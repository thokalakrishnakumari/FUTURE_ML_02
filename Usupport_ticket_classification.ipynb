# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

tickets = [
    "Internet is not working",
    "Forgot my password",
    "Payment failed",
    "Need account access",
    "Website is slow"
]

labels = [
    "Technical",
    "Account",
    "Billing",
    "Account",
    "Technical"
]

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(tickets)

model = MultinomialNB()
model.fit(X, labels)

new_ticket = ["My internet connection is very slow"]
new_X = vectorizer.transform(new_ticket)

prediction = model.predict(new_X)

print("Ticket:", new_ticket[0])
print("Predicted Category:", prediction[0])
# Out:
# Ticket: My internet connection is very slow
# Predicted Category: Technical
